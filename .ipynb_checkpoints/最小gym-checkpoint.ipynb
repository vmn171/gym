# %%
import gym

env = gym.make('CartPole-v0').unwrapped  # 创建一个环境
#env = gym.make('Acrobot-v1')
#env = gym.make('MountainCar-v0')
#env = gym.make('Pendulum-v0')
#env = gym.make('Pong-v0')
for episode in range(20):  # 循环20个片段
    observation = env.reset()  # 环境的观察值
    for t in range(100):  # 每个片段最多20步
        screen = env.render()  # 渲染环境
        action = env.action_space.sample()  # 动作位环境的动作空间中采样
        observation, reward, done, info = env.step(action)  # 环境执行动作，返回新的观察值，奖励，done，info
        if done:  # 如果环境的done=True
            #print("Episode finished after {} timesteps".format(t + 1))
            break
# Out:
# [-0.00641297  0.00104846  0.04504688  0.00397979]
# (-0.006392003823204268, 0.19549639776859912, 0.04512647313623256, -0.27415692929876473)
# (-0.0024820758678322855, -0.00023940113820189457, 0.039643334550257266, 0.032410553394113584)
# (-0.0024868638905963234, -0.19590677075870425, 0.040291545618139538, 0.33733309352361368)
# (-0.0064049993057704088, -0.0013806566838547862, 0.047038207488611809, 0.057623246502789327)
# (-0.0064326124394475043, -0.19714438747991142, 0.048190672418667597, 0.36476817732274797)
# (-0.010375500189045733, -0.39291689934023538, 0.055486035965122554, 0.67224859769872136)
# (-0.018233838175850441, -0.19860834295142479, 0.068931007919096982, 0.39753883680423274)
# (-0.022206005034878937, -0.0045285840555109869, 0.07688178465518164, 0.1273602212168905)
# (-0.022296576715989159, -0.20066291668123198, 0.079428989079519452, 0.4432736479701801)
# (-0.026309835049613799, -0.006749426331240066, 0.088294462038923049, 0.17664805103265563)
# ...
